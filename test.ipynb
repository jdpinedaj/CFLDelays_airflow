# %%
import pandas as pd
pd.get_option("display.max_columns", None)
pd.get_option("display.max_rows", None)
# Out:
# 60

# %%
 source = pd.read_excel('dags/data/WAGON.xlsx', sheet_name=1)

# %%
source.shape
# Out:
# (14, 43)

# %%
source.columns.tolist()
# Out:
# ['IDWAGON_MODELE',
#  'Modele_wagon',
#  'Caracteristiques',
#  'Type_wagon',
#  'Lettres_categories',
#  'Enr_actif',
#  'IDUtilisateur_creation',
#  'DateH_creation',
#  'IDUtilisateur_maj',
#  'DateH_maj',
#  'Frein_regime',
#  'Vitesse_maxi',
#  'Longueur_HT',
#  'Longueur_HTp',
#  'Nb_Plateaux',
#  'Longueur_utile',
#  'Hauteur_chargt',
#  'Charge_utile',
#  'Charge_TEU',
#  'Charge_essieu',
#  'Roue_diam',
#  'Courbure_rayon',
#  'Plancher_hauteur_rail',
#  'Poche_longueur',
#  'Nb_essieux',
#  'Charge_AS',
#  'Charge_ASS',
#  'Charge_BS',
#  'Charge_BSS',
#  'Charge_CS',
#  'Charge_CSS',
#  'Charge_DS',
#  'Charge_DSS',
#  'Nb_Positions_maxi',
#  'IDNHM_vide',
#  'IDNHM_Charge',
#  'Tare',
#  'Capacite_Pe',
#  'Capacite_Pf',
#  'Capacite_Pg',
#  'Chargement_mode',
#  'CentreCout',
#  'Regroupement_analytique_wagon']

# %%
 source.head()
# Out:
#    IDINCIDENT_CONCERNE  IDINCIDENT  IDTRAIN_UTI  IDTRAIN_WAGON  \
# 0                  211         203          NaN            NaN
# 1                  212         204          NaN       202074.0
# 2                  214         205      71237.0            NaN
# 3                  215         206          NaN            NaN
# 4                  216         207          NaN            NaN
#
#    IDUtilisateur_creation           DateH_creation  IDUtilisateur_maj  \
# 0                      57  2020-01-06 10:45:57.680                NaN
# 1                      31  2020-01-07 15:13:28.790                NaN
# 2                      31  2020-01-07 15:18:36.470                NaN
# 3                      83  2020-01-09 20:34:11.200                NaN
# 4                      83  2020-01-09 20:44:54.270                NaN
#
#    DateH_maj Unite  IDCOMMANDE_UTI  IDAGRES  IDFACTURE  IDTRAIN_LOT  IDWAGON  \
# 0        NaN     T             NaN      NaN        NaN          NaN      NaN
# ...

# %%
target_fields = source.columns.tolist()
target_fields
# Out:
# ['IDTRAIN_WAGON',
#  'IDWAGON',
#  'IDTRAIN_LOT',
#  'Num_Position',
#  'IDUtilisateur_creation',
#  'DateH_creation',
#  'IDUtilisateur_maj',
#  'DateH_maj',
#  'IDWAGON_MODELE',
#  'Top_wagon_maitre']

# %%
rows = source.values.tolist()
rows
# Out:
# [[138270, nan, 7138, 0, 31, '2019-09-03 18:17:27.237', 0, nan, 1, 0],
#  [138271, nan, 7138, 1, 31, '2019-09-03 18:17:27.243', 0, nan, 2, 0],
#  [138272, nan, 7138, 2, 31, '2019-09-03 18:17:27.247', 0, nan, 2, 0],
#  [138273, nan, 7138, 3, 31, '2019-09-03 18:17:27.253', 0, nan, 2, 0],
#  [138274, nan, 7138, 4, 31, '2019-09-03 18:17:27.260', 0, nan, 2, 0],
#  [138275, nan, 7138, 5, 31, '2019-09-03 18:17:27.267', 0, nan, 2, 0],
#  [138276, nan, 7138, 6, 31, '2019-09-03 18:17:27.270', 0, nan, 2, 0],
#  [138277, nan, 7138, 7, 31, '2019-09-03 18:17:27.277', 0, nan, 2, 0],
#  [138278, nan, 7138, 8, 31, '2019-09-03 18:17:27.283', 0, nan, 2, 0],
#  [138279, nan, 7138, 9, 31, '2019-09-03 18:17:27.290', 0, nan, 2, 0],
#  [138280, nan, 7138, 10, 31, '2019-09-03 18:17:27.297', 0, nan, 2, 0],
#  [138281, nan, 7138, 11, 31, '2019-09-03 18:17:27.300', 0, nan, 2, 0],
#  [138282, nan, 7138, 12, 31, '2019-09-03 18:17:27.307', 0, nan, 2, 0],
# ...

# %%
create_incident_concerne_table
create_incidents_table
create_station_table
create_terminal_table
create_train_etape_table
create_train_jalon_table
create_train_lot_table
create_train_position_table
create_train_wagon_table
create_train_table
create_wagon_capacite_table
create_wagon_position_table
create_wagon_table
create_wagon_modelle_table
